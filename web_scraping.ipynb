# %%
from selenium import webdriver
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
import pandas as pd

# %%
chrome_path=r"/Users/jamilahalharbi/Desktop/chromedriver"

# %%
driver=webdriver.Chrome(chrome_path)
# Out:
# /opt/anaconda3/envs/J-Rabeh/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.

# %%
driver.get('https://syarah.com/cars/%D8%AD%D8%B1%D8%A7%D8%AC-%D8%B3%D9%8A%D8%A7%D8%B1%D8%A7%D8%AA')

# %%
import requests 
from bs4 import BeautifulSoup
import csv
from itertools import zip_longest
html = driver.page_source
soup = BeautifulSoup(html)

# %%
result= requests.get("https://syarah.com/cars/%D8%AD%D8%B1%D8%A7%D8%AC-%D8%B3%D9%8A%D8%A7%D8%B1%D8%A7%D8%AA")

# %%
src=result.content

# %%
soup=BeautifulSoup(src,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <base href="/"/>
# <title> حراج سيارات  للبيع في السعودية  | موقع سيارة </title>
# <meta charset="utf-8"/>
# <link href="/assets/images/favicon.ico?v1.8" rel="icon" type="image/ico"/>
# <meta content="IE=edge,chrome=1" httpequiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="app-id=1066260672" name="apple-itunes-app-custom"/>
# <meta content="app-id=app.com.syarah" name="google-play-app"/>
# <meta content="https://syarah.com/assets/images/favicon.ico?v=1.8" name="msapplication-TileImage"/>
# <meta content="تصفح الآلاف السيارات الجديدة والمستعملة في السعودية على حراج سيارة من المعارض والأفراد وتواصل معهم مباشرة" name="description"/>
# <link href="https://syarahcdn.syarah.com/manifest.json" rel="manifest"/>
# <link href="https://fonts.googleapis.com/css?family=Cairo:400,700,900" rel="stylesheet"/>
# ...

# %%
car_name=[]
fuel_type=[]
gear_type=[]
mileage=[]
color=[]
model=[]
price=[]
engine_size=[]
links_with_text = []
car_type=[]
h=[]
j=[]
k=[]
u=[]
r=[]
e=[]
o=[]
u=[]
y=[]
q=[]
m=[]
v=[]
c=[]
z=[]

# %%
file_list=[link_1,car_name,car_type,h,j,k,u,r,e,o,u,y,q,m,v,c]
exported=zip_longest(*file_list)
with open("/Users/jamilahalharbi/Desktop/Cars.csv","w")as myfile:
    wr=csv.writer(myfile)
    wr.writerow(["link_1","car_name","car_type","h","j","k","u","r","e","o","u","y","q","m","v","c"])
    wr.writerows(exported)

# %%
link_1=[]
all_link=driver.find_elements_by_xpath('//*[@id="root"]/div[1]/main/section/div[1]/div[2]/a')
for link in all_link:
    link_1.append(link.get_attribute("href"))

# %%
df=pd.read_csv('/Users/jamilahalharbi/Desktop/Cars.csv')

# %%
df["link_1"]
# Out:
# 0     https://syarah.com/car/%D9%87%D9%88%D9%86%D8%A...
# 1     https://syarah.com/car/%D9%87%D9%88%D9%86%D8%A...
# 2     https://syarah.com/car/%D9%84%D9%8A%D9%86%D9%8...
# 3     https://syarah.com/car/%D9%81%D9%88%D8%B1%D8%A...
# 4     https://syarah.com/car/%D9%87%D8%A7%D9%81%D8%A...
# 5     https://syarah.com/car/%D9%87%D9%88%D9%86%D8%A...
# 6     https://syarah.com/car/%D8%AA%D9%88%D9%8A%D9%8...
# 7     https://syarah.com/car/%D9%84%D9%83%D8%B2%D8%B...
# 8     https://syarah.com/car/%D8%AA%D9%88%D9%8A%D9%8...
# 9     https://syarah.com/car/%D9%87%D9%88%D9%86%D8%A...
# 10    https://syarah.com/car/%D9%87%D9%88%D9%86%D8%A...
# 11    https://syarah.com/car/%D8%AA%D9%88%D9%8A%D9%8...
# 12    https://syarah.com/car/%D9%87%D9%88%D9%86%D8%A...
# 13    https://syarah.com/car/%D9%87%D9%88%D9%86%D8%A...
# 14    https://syarah.com/car/%D8%AA%D9%88%D9%8A%D9%8...
# 15    https://syarah.com/car/%D8%AA%D9%88%D9%8A%D9%8...
# 16    https://syarah.com/car/%D8%AC%D9%8A%D8%A8-%D8%...
# ...

# %%
df89
# Out:
# <_io.TextIOWrapper name='/Users/jamilahalharbi/Desktop/Caars.csv' mode='w' encoding='UTF-8'>

# %%
df3=[]
for link in link_1:
    result=requests.get(link)
    src=result.content
    soup=BeautifulSoup(src,"lxml")
    res=""
    car_types=soup.find("div",{"class":"carDetailesCC"})
    for strong in car_types.find_all({"src":"https://syarahcdn.syarah.com/syarah/bundles/Extention.svg"}):
        print(soup.find("strong"))
        #res+= strong.text+" "
        #df3.append(res)

# %%
df3
# Out:
# []

# %%
posts=driver.find_elements_by_class_name("currentPrice")
# Out:
# /opt/anaconda3/envs/J-Rabeh/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   """Entry point for launching an IPython kernel.

# %%
for post in posts:
    price=post.text
    print(price)
# Out:
# 50,000 ريال
# 69,000 ريال
# 38,500 ريال
# 82,900 ريال
# 88,000 ريال
# 55,000 ريال
# 165,000 ريال
# على السوم
# 68,000 ريال
# 94,000 ريال
# 80,000 ريال
# 95,000 ريال
# 70,000 ريال
# 82,000 ريال
# 95,000 ريال
# 78,000 ريال
# 60,000 ريال
# 53,000 ريال
# 112,000 ريال
# 138,000 ريال
# 105,000 ريال
# 103,000 ريال
# 90,000 ريال
# 110,000 ريال
# على السوم
# 148,000 ريال

# %%
posts=driver.find_elements_by_class_name("location")
# Out:
# /opt/anaconda3/envs/J-Rabeh/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   """Entry point for launching an IPython kernel.

# %%
for post in posts:
    location=post.text
    print(location)
# Out:
# الرياض
# الرياض
# مستعملة
# مستعملة
# جديدة
# جديدة
# الرياض
# جدة
# الرياض
# الرياض
# الرياض
# الرياض
# الرياض
# الرياض
# الرياض
# الرياض
# الرياض
# الرياض
# الرياض
# عسير
# عسير
# الرياض
# الرياض
# الرياض
# الطائف
# جدة

# %%
posts=driver.find_elements_by_class_name("distance")
# Out:
# /opt/anaconda3/envs/J-Rabeh/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   """Entry point for launching an IPython kernel.

# %%
for post in posts:
    d=post.text
    print(d)
# Out:
# مستعملة
# مستعملة
# 124,400 كم
# 88,665 كم
#
#
# مستعملة
# مستعملة
# مستعملة
# مستعملة
# مستعملة
# مستعملة
# مستعملة
# مستعملة
# مستعملة
# مستعملة
# مستعملة
# مستعملة
# مستعملة
# مستعملة
# مستعملة
# جديدة
# مستعملة
# جديدة
# مستعملة
# جديدة

# %%
el = """
<div class="container postMainColumns"><div><section class="carInfoCC"><h2><span>تفاصيل السيارة</span></h2><div class="carDetailesCC"><div><img src="https://syarahcdn.syarah.com/syarah/bundles/Key.svg" alt=""><label>الماركة:</label><strong>كيا</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/Type.svg" alt=""><label>النوع:</label><strong>K5</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/Model.svg" alt=""><label>السنة:</label><strong>2022</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/to.svg" alt=""><label>الوارد:</label><strong>سعودي</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/Color.svg" alt=""><label>اللون:</label><strong>لون آخر</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/Specs.svg" alt=""><label>المواصفات:</label><strong>ستاندر</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/fuel.svg" alt=""><label>نوع الوقود:</label><strong>بنزين</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/Gear.svg" alt=""><label>نوع القير:</label><strong>اوتوماتيك</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/drivetrain.svg" alt=""><label>نوع الدفع:</label><strong>دفع امامي</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/engine_size.svg" alt=""><label>حجم المحرك:</label><strong>2.0</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/car book.svg" alt=""><label>الحالة:</label><strong>جديدة</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/meter.svg" alt=""><label>الممشى:</label><strong>0 كم</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/City.svg" alt=""><label>المنطقة:</label><strong>المدينة</strong></div></div><div><div class="accContainerN"><div class="singleinfoRowN open_CC"><h3> مواصفات اضافية </h3><div><p class="contentFromAdminCC"> </p></div></div></div></div></section></div><div><div class="columnContainer"><div class="sellerInfo"><h5>تفاصيل البائع</h5><div class="dealerSeller"><div class="dealerSellerImgHolder"><img src="https://syarahcdn.syarah.com/syarah/dealers/1356/0x300/orignal-1636358189-221.png" alt=""></div><div><span class="mwthContainer"><img src="https://syarahcdn.syarah.com/syarah/bundles/mwth8.svg" alt=""><span>معرض موثق</span></span><h5>صقر الحارثي للسيارات</h5><div class="locationMoreCars"><span>المدينة, طريق الجامعات</span><a href="/معرض/صقر_الحارثي_للسيارات/1356">48 سيارة</a></div></div></div></div><div class="reportContainer "><div><img src="https://syarahcdn.syarah.com/syarah/bundles/outlined.svg" alt=""><span>بلغ عن إساءة</span></div></div></div></div></div>"""

soup=BeautifulSoup(el,"lxml")
car_types=soup.find("div",{"class":"carDetailesCC"})
print(car_types.next_element.find("strong").text)
# Out:
# كيا

# %%
el = """
<div class="container postMainColumns"><div><section class="carInfoCC"><h2><span>تفاصيل السيارة</span></h2><div class="carDetailesCC"><div><img src="https://syarahcdn.syarah.com/syarah/bundles/Key.svg" alt=""><label>الماركة:</label><strong>كيا</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/Type.svg" alt=""><label>النوع:</label><strong>K5</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/Model.svg" alt=""><label>السنة:</label><strong>2022</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/to.svg" alt=""><label>الوارد:</label><strong>سعودي</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/Color.svg" alt=""><label>اللون:</label><strong>لون آخر</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/Specs.svg" alt=""><label>المواصفات:</label><strong>ستاندر</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/fuel.svg" alt=""><label>نوع الوقود:</label><strong>بنزين</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/Gear.svg" alt=""><label>نوع القير:</label><strong>اوتوماتيك</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/drivetrain.svg" alt=""><label>نوع الدفع:</label><strong>دفع امامي</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/engine_size.svg" alt=""><label>حجم المحرك:</label><strong>2.0</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/car book.svg" alt=""><label>الحالة:</label><strong>جديدة</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/meter.svg" alt=""><label>الممشى:</label><strong>0 كم</strong></div><div><img src="https://syarahcdn.syarah.com/syarah/bundles/City.svg" alt=""><label>المنطقة:</label><strong>المدينة</strong></div></div><div><div class="accContainerN"><div class="singleinfoRowN open_CC"><h3> مواصفات اضافية </h3><div><p class="contentFromAdminCC"> </p></div></div></div></div></section></div><div><div class="columnContainer"><div class="sellerInfo"><h5>تفاصيل البائع</h5><div class="dealerSeller"><div class="dealerSellerImgHolder"><img src="https://syarahcdn.syarah.com/syarah/dealers/1356/0x300/orignal-1636358189-221.png" alt=""></div><div><span class="mwthContainer"><img src="https://syarahcdn.syarah.com/syarah/bundles/mwth8.svg" alt=""><span>معرض موثق</span></span><h5>صقر الحارثي للسيارات</h5><div class="locationMoreCars"><span>المدينة, طريق الجامعات</span><a href="/معرض/صقر_الحارثي_للسيارات/1356">48 سيارة</a></div></div></div></div><div class="reportContainer "><div><img src="https://syarahcdn.syarah.com/syarah/bundles/outlined.svg" alt=""><span>بلغ عن إساءة</span></div></div></div></div></div>"""

soup=BeautifulSoup(el,"lxml")
for node in soup.find_all("div",{"class":"carDetailesCC"}):
    print(''.join(node.find_all('strong')

# %%
nxt = nxt.next_element
print(nxt.next_element.find("strong"))

# %%
nxt = nxt.next_element
print(nxt.next_element.find("strong"))
